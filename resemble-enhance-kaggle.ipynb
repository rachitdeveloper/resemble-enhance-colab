# %%
# download Repo
# !git clone https://github.com/resemble-ai/resemble-enhance.git

# %%
# First run then restert runtime
# %cd /kaggle/working/resemble-enhance
# !pip install -r requirements.txt

# %%
#running on colab or kaggle
# Starting with RemoteMoe

# %cd /kaggle/working/resemble-enhance
# !mkdir  ~/.ssh/
# !touch  ~/.ssh/known_hosts
# !ssh-keyscan -t rsa remote.moe >> ~/.ssh/known_hosts
# !rm /root/.ssh/id_rsa
# !ssh-keygen -t rsa -b 4096 -f /root/.ssh/id_rsa -q -N ""
# !python /kaggle/working/resemble-enhance/app.py & ssh -R 80:127.0.0.1:7860 -o StrictHostKeyChecking=no -i /root/.ssh/id_rsa remote.moe

# %%
#running locally
# !python app.py
